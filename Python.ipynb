# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitaj05/Python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello \nworld") #\n means next line
# Out:
# hello
# world

# %%
'''
Python is a case sensitive language
Python's character set:
alphabets caps and no caps, numbers, +, - , /, *, %, whitespaces: blank space, tab (\t), newline
'''
# Out:
# "\nPython is a case sensitive language\nPython's character set:\nalphabets caps and no caps, numbers, +, - , /, *, %, whitespaces: blank space, tab (\t), newline\n"

# %%
#one instruction in one line: for ex you are saying
name="harshita"
age=18

#you cant put these two in the same line otherwise it shows error

# %%
print(type(age))

#type and print are functions
# Out:
# <class 'int'>

# %%
#datatypes: string, integer, float, boolean,
'''
different styles of writing variable names:
snake_case
camelCaseAlphabet
PascalCase
'''
# Out:
# '\ndifferent styles of writing variable names:\nsnake_case\ncamelCaseAlphabet\nPascalCase\n'

# %%
#"%" IS MODULO WHICH MEANS REMAINDER AFTER DIVISION
#"**" MEANS POWER/ EXPONENTIAl
# == means maths wala equal
# != means NOT EQUAL TO

# %%
#assignment operators
a="b" #this means ham b value ko a ke andar store kar rahe hn
c=5
c=c+1 #c+=1
print(c)
# Out:
# 6

# %%
#logical operators: not (TRUE VALUE KO FALSE, FALSE KO TRUE KR DETA H), and (gives true iff both values are true), or (gives true when either one is true)
print((5>3)and(3<8))
print((5<3)and(3<8))
# Out:
# True
# False

# %%
'''
in python, we also have bitwise operators and membership operators along with arithemtaic, relational, logical, assignment
operator precendence:
  ()
  **
  *, /, %
  +, -
  relational operators
  not
  and
  or
'''
# Out:
# '\nin python, we also have bitwise operators and membership operators along with arithemtaic, relational, logical, assignment\noperator precendence: \n  ()\n  **\n  *\n  /\n  %\n  +\n  -\n  relational operators\n  not\n  and\n  or\n'

# %%
'''
type conversion is implicit: python khud kr deta hai
casting: jab ham khudse convert krte hn according to compatible combinations (int to float, float to int, int to boolean)
'''

ans1 = int(5+10.0) #casting
ans2 = 5+10.0 #conversion
print(ans1,", ",ans2)
print(type(ans1))
print(type(ans2))
# Out:
# 15 ,  15.0
# <class 'int'>
# <class 'float'>

# %%
#take INPUT from USER: INPUT function

username=input("enter your name: ")
print("welcome",username)
# Out:
# enter your name: harshita
# welcome harshita

# %%
#average of two values
num1=input("enter first number: ")
num2=input("enter second number: ")
avg=int((int(num1)+int(num2))/2)
print("average is:",avg)
print(type(avg))
# Out:
# enter first number: 5
# enter second number: 7
# average is: 6
# <class 'int'>

# %%
s1=input("first number:")
s2=input("second number:")
sum=s1+s2

print(sum)

#input always takes value as STRING, hence 56 ka operation is CONCATENATION

sN1=int(input("first number:"))
sN2=int(input("second number:"))
sumN=sN1+sN2

print(sumN)
# Out:
# first number:5
# second number:6
# 56
# first number:5
# second number:6
# 11

# %%
'''
Conditional statemnets: if, elif, else
after if, elif, else, put something jiski value boolean (T/F) ho
'''

age=18
if age<18:
  print("cannot drive, cannot drink"),
elif age>=21:
  print("can drive, can drink"),
else:
  print("can drive, cannot drink")
# Out:
# can drive, cannot drink

# %%
login_name=input("enter your login name:")
password=input("enter your password:")

if (login_name=="admin" and password=="pass"):
  print("LOGIN SUCCESSFUL"),
elif (login_name!="admin"):
  print("invalid login name ID"),
elif (password!="pass"):
  print("invalid password")
# Out:
# enter your login name:harshita
# enter your password:pass
# invalid login name ID

# %%
login_name=input("enter your login name:")
password=input("enter your password:")

if (login_name=="admin" and password=="pass"):
  print("LOGIN SUCCESSFUL"),
elif (login_name!="admin"):
  print("invalid login name ID"),
elif (password!="pass"):
  print("invalid password")
# Out:
# enter your login name:admin
# enter your password:harshita
# invalid password

# %%
plogin_name=input("enter your login name:")
password=input("enter your password:")

if (login_name=="admin" and password=="pass"):
  print("LOGIN SUCCESSFUL"),
elif (login_name!="admin"):
  print("invalid login name ID"),
elif (password!="pass"):
  print("invalid password")
# Out:
# enter your login name:admin
# enter your password:pass
# LOGIN SUCCESSFUL

# %%
from logging import log
#NESTING: ek condiiton me hi different conditions

login_name=input("enter your login name:")
password=input("enter your password:")

if (login_name=="admin" and password=="pass"):
  print("LOGIN SUCCESSFUL"),
else:
  if login_name!="admin":
    print("invalid username")
  else:
    print("incorrect password")
# Out:
# enter your login name:admin
# enter your password:harsh
# incorrect password
